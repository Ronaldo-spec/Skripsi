# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf

from PIL import Image
from numpy import asarray

from tensorflow import keras
from keras.utils import np_utils
from tensorflow.keras import datasets,layers, models

# %% [markdown]
# # CONNECT DENGAN DIRECTORY

# %%
base_dir = "blobs.rect/coba2/"
latih =  "rect.dataset/latih"
validasi = "rect.dataset/validasi"
testing = "rect.dataset/testing"
# !ls "D:\TUGAS\Kuliah\Semester8\SourcesCode\SimulasiCNN\blobs.fit"
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
bahan_dir = os.path.join(base_dir)
train_dir = os.path.join(latih)
valid_dir = os.path.join(validasi)
test_dir = os.path.join(testing)

# %%
gradeA_dir = os.path.join(bahan_dir, 'gradeA/')
gradeB_dir = os.path.join(bahan_dir, 'gradeB/')
gradeC_dir = os.path.join(bahan_dir, 'gradeC/')

print("Jumlah data tiap kelas")
print("Jumlah gambar grade  A : ", len(os.listdir(gradeA_dir)))
print("Jumlah gambar grade  B : ", len(os.listdir(gradeB_dir)))
print("Jumlah gambar grade  C : ", len(os.listdir(gradeC_dir)))
print("Total dataset : ", len(os.listdir(gradeA_dir)) + len(os.listdir(gradeB_dir)) + len(os.listdir(gradeC_dir)))
# Out:
# Jumlah data tiap kelas
# Jumlah gambar grade  A :  580
# Jumlah gambar grade  B :  580
# Jumlah gambar grade  C :  580
# Total dataset :  1740

# %%
# direktori isi latih/training
train_gradeA = os.path.join(train_dir, 'gradeA/')
train_gradeB = os.path.join(train_dir, 'gradeB/')
train_gradeC = os.path.join(train_dir, 'gradeC/')

# direktori isi validasi
valid_gradeA = os.path.join(valid_dir, 'gradeA/')
valid_gradeB = os.path.join(valid_dir, 'gradeB/')
valid_gradeC = os.path.join(valid_dir, 'gradeC/')

# direktori isi test
test_gradeA = os.path.join(test_dir, 'gradeA/')
test_gradeB = os.path.join(test_dir, 'gradeB/')
test_gradeC = os.path.join(test_dir, 'gradeC/')

# %% [markdown]
# # MEMBAGI DATASET MENJADI DATA TRAINING DAN DATA VALIDATION

# %%
import random
from shutil import copyfile

def train_val_split(source, train, val, test, train_ratio, val_ratio):
  total_size = len(os.listdir(source))
  train_size = int(train_ratio * total_size)
  val_size = int(val_ratio * total_size)
  test_size = total_size - train_size - val_size

  randomized  = random.sample(os.listdir(source), total_size)
  train_files = randomized[0:train_size]
  val_files   = randomized[train_size:train_size+val_size]
  test_files = randomized[train_size+val_size:total_size]

  for i in train_files:
    i_file = source + i
    destination = train + i
    copyfile(i_file, destination)

  for i in val_files:
    i_file = source + i
    destination = val + i
    copyfile(i_file, destination)
  for i in test_files:
    i_file = source + i
    destination = test + i
    copyfile(i_file, destination)

# jumlah pembagian data training dan testing
train_ratio = 0.9
val_ratio = 0.05

#pembagian training dan validasi 
#gradeA
source_00 = gradeA_dir
train_00  = train_gradeA
val_00    = valid_gradeA
test_00   = test_gradeA
train_val_split(source_00, train_00, val_00, test_00, train_ratio, val_ratio )

#gradeB
source_01 = gradeB_dir
train_01  = train_gradeB
val_01    = valid_gradeB
test_01   = test_gradeB
train_val_split(source_01, train_01, val_01, test_01, train_ratio, val_ratio )

#gradeC
source_02 = gradeC_dir
train_02  = train_gradeC
val_02    = valid_gradeC
test_02   = test_gradeC
train_val_split(source_02, train_02, val_02, test_02, train_ratio, val_ratio)

# %%
print("Jumlah all grade A   : ", len(os.listdir(gradeA_dir)))
print("Jumlah train grade A : ", len(os.listdir(train_gradeA)))
print("Jumlah validation grade A   : ", len(os.listdir(valid_gradeA)))
print("Jumlah testing grade A   : ", len(os.listdir(test_gradeA)))

print("\nJumlah all grade B   : ", len(os.listdir(gradeB_dir)))
print("Jumlah train grade B : ", len(os.listdir(train_gradeB)))
print("Jumlah validation grade B   : ", len(os.listdir(valid_gradeB)))
print("Jumlah testing grade B   : ", len(os.listdir(test_gradeB)))

print("\nJumlah all grade C   : ", len(os.listdir(gradeC_dir)))
print("Jumlah train grade C : ", len(os.listdir(train_gradeC)))
print("Jumlah validation grade C   : ", len(os.listdir(valid_gradeC)))
print("Jumlah testing grade C   : ", len(os.listdir(test_gradeC)))

# %% [markdown]
# # MOBILENET V2

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen       = ImageDataGenerator(
    rescale         = 1./255
)

val_datagen = ImageDataGenerator(
    rescale         = 1./255
)
test_datagen = ImageDataGenerator(
    rescale         = 1./255
)

# %%
IMG_SIZE = (96,96)
BATCH_SIZE = 32

# train_dir = os.path.join(base_dir, 'latih')
# validation_dir = os.path.join(base_dir, 'validasi')

# train_dataset = tf.keras.utils.image_dataset_from_directory(train_dir, shuffle=True, batch_size=BATCH_SIZE, image_size=IMG_SIZE, class_mode= 'categorical')
# validation_dataset = tf.keras.utils.image_dataset_from_directory(validation_dir, shuffle=True, batch_size=BATCH_SIZE, image_size=IMG_SIZE, class_mode= 'categorical')

train_dataset = train_datagen.flow_from_directory(
    train_dir,
    target_size = IMG_SIZE,
    batch_size = BATCH_SIZE,
    shuffle    = False,
    class_mode = 'categorical',
    color_mode = 'rgb'
)
valid_dataset = val_datagen.flow_from_directory(
    valid_dir,
    target_size = IMG_SIZE,
    batch_size = BATCH_SIZE,
    shuffle    = False,
    class_mode = 'categorical',
    color_mode = 'rgb'
)
test_dataset = test_datagen.flow_from_directory(
    test_dir,
    target_size = IMG_SIZE,
    batch_size = BATCH_SIZE,
    shuffle    = False,
    class_mode = 'categorical',
    color_mode = 'rgb'
)
# Out:
# Found 1566 images belonging to 3 classes.
# Found 87 images belonging to 3 classes.
# Found 87 images belonging to 3 classes.

# %%
IMG_SHAPE = IMG_SIZE + (3,)
MobileNetV2 = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE, include_top=False, weights='imagenet')

for layer in MobileNetV2.layers:
    layer.trainable = False

# %% [markdown]
# # UJI COBA CUSTOM MODEL KE-1

# %%
x = MobileNetV2.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
# x = tf.keras.layers.Dropout(0.2)(x)
output = tf.keras.layers.Dense(3, activation='softmax')(x)
modelku = tf.keras.Model(inputs=MobileNetV2.input, outputs = output)

# %%
modelku.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 96, 96, 3)]  0           []
#
#  Conv1 (Conv2D)                 (None, 48, 48, 32)   864         ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalization)  (None, 48, 48, 32)   128         ['Conv1[0][0]']
#
#  Conv1_relu (ReLU)              (None, 48, 48, 32)   0           ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (Depth  (None, 48, 48, 32)  288         ['Conv1_relu[0][0]']
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 48, 48, 32)  128         ['expanded_conv_depthwise[0][0]']
#  tchNormalization)
#
#  expanded_conv_depthwise_relu (  (None, 48, 48, 32)  0           ['expanded_conv_depthwise_BN[0][0
#  ReLU)                                                           ]']
#
#  expanded_conv_project (Conv2D)  (None, 48, 48, 16)  512         ['expanded_conv_depthwise_relu[0]
#                                                                  [0]']
#
#  expanded_conv_project_BN (Batc  (None, 48, 48, 16)  64          ['expanded_conv_project[0][0]']
#  hNormalization)
#
#  block_1_expand (Conv2D)        (None, 48, 48, 96)   1536        ['expanded_conv_project_BN[0][0]'
#                                                                  ]
#
#  block_1_expand_BN (BatchNormal  (None, 48, 48, 96)  384         ['block_1_expand[0][0]']
#  ization)
#
#  block_1_expand_relu (ReLU)     (None, 48, 48, 96)   0           ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D)    (None, 49, 49, 96)   0           ['block_1_expand_relu[0][0]']
#
#  block_1_depthwise (DepthwiseCo  (None, 24, 24, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 24, 24, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 24, 24, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 24, 24, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 24, 24, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 24, 24, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 24, 24, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 24, 24, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 24, 24, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 24, 24, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 24, 24, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 24, 24, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 24, 24, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 24, 24, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 24, 24, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 24, 24, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 24, 24, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 25, 25, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 12, 12, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 12, 12, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 12, 12, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 12, 12, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 12, 12, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 12, 12, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 12, 12, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 12, 12, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 12, 12, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 12, 12, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 12, 12, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 12, 12, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 12, 12, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 12, 12, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 12, 12, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 12, 12, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 12, 12, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 12, 12, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 12, 12, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 12, 12, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 12, 12, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 12, 12, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 12, 12, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 12, 12, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 12, 12, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 12, 12, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 13, 13, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 6, 6, 192)   1728        ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 6, 6, 192)   768         ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 6, 6, 192)    0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 6, 6, 64)     12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 6, 6, 64)    256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 6, 6, 384)    24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 6, 6, 384)   1536        ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 6, 6, 384)    0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 6, 6, 384)   3456        ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 6, 6, 384)   1536        ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 6, 6, 384)    0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 6, 6, 64)     24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 6, 6, 64)    256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 6, 6, 64)     0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 6, 6, 384)    24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 6, 6, 384)   1536        ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 6, 6, 384)    0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 6, 6, 384)   3456        ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 6, 6, 384)   1536        ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 6, 6, 384)    0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 6, 6, 64)     24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 6, 6, 64)    256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 6, 6, 64)     0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 6, 6, 384)    24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 6, 6, 384)   1536        ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 6, 6, 384)    0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 6, 6, 384)   3456        ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 6, 6, 384)   1536        ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 6, 6, 384)    0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 6, 6, 64)     24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 6, 6, 64)    256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 6, 6, 64)     0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 6, 6, 384)    24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 6, 6, 384)   1536        ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 6, 6, 384)    0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 6, 6, 384)   3456        ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 6, 6, 384)   1536        ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 6, 6, 384)   0           ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 6, 6, 96)     36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 6, 6, 96)    384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 6, 6, 576)    55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 6, 6, 576)   2304        ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 6, 6, 576)    0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 6, 6, 576)   5184        ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 6, 6, 576)   2304        ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 6, 6, 576)   0           ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 6, 6, 96)     55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 6, 6, 96)    384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 6, 6, 96)     0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 6, 6, 576)    55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 6, 6, 576)   2304        ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 6, 6, 576)    0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 6, 6, 576)   5184        ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 6, 6, 576)   2304        ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 6, 6, 576)   0           ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 6, 6, 96)     55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 6, 6, 96)    384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 6, 6, 96)     0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 6, 6, 576)    55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 6, 6, 576)   2304        ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 6, 6, 576)    0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 7, 7, 576)    0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 3, 3, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 3, 3, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 3, 3, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 3, 3, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 3, 3, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 3, 3, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 3, 3, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 3, 3, 960)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 3, 3, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 3, 3, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 3, 3, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 3, 3, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 3, 3, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 3, 3, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 3, 3, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 3, 3, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 3, 3, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 3, 3, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 3, 3, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 3, 3, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 3, 3, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 3, 3, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 3, 3, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 3, 3, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 3, 3, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 3, 3, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 3, 3, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 3, 3, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 3, 3, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 3, 3, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 3, 3, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 3, 3, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 3, 3, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 3, 3, 1280)   0           ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1280)        0           ['out_relu[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 3)            3843        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 2,261,827
# Trainable params: 3,843
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________

# %%
base_learning_rate = 0.0001
modelku.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
                loss="categorical_crossentropy",
                metrics=['accuracy'])

# %%
history = modelku.fit(train_dataset, epochs=100, validation_data=valid_dataset)
# Out:
# Epoch 1/100
# 49/49 [==============================] - 17s 231ms/step - loss: 1.0610 - accuracy: 0.3934 - val_loss: 0.9082 - val_accuracy: 0.5287
# Epoch 2/100
# 49/49 [==============================] - 10s 207ms/step - loss: 0.8367 - accuracy: 0.5932 - val_loss: 0.7373 - val_accuracy: 0.7011
# Epoch 3/100
# 49/49 [==============================] - 10s 207ms/step - loss: 0.7018 - accuracy: 0.7254 - val_loss: 0.6250 - val_accuracy: 0.7356
# Epoch 4/100
# 49/49 [==============================] - 10s 206ms/step - loss: 0.6001 - accuracy: 0.7822 - val_loss: 0.5361 - val_accuracy: 0.8391
# Epoch 5/100
# 49/49 [==============================] - 10s 206ms/step - loss: 0.5262 - accuracy: 0.8352 - val_loss: 0.4805 - val_accuracy: 0.8276
# Epoch 6/100
# 49/49 [==============================] - 10s 204ms/step - loss: 0.4685 - accuracy: 0.8633 - val_loss: 0.4270 - val_accuracy: 0.8736
# Epoch 7/100
# 49/49 [==============================] - 10s 205ms/step - loss: 0.4229 - accuracy: 0.8838 - val_loss: 0.3856 - val_accuracy: 0.8851
# Epoch 8/100
# 49/49 [==============================] - 10s 205ms/step - loss: 0.3846 - accuracy: 0.8959 - val_loss: 0.3587 - val_accuracy: 0.8966
# Epoch 9/100
# 49/49 [==============================] - 10s 211ms/step - loss: 0.3585 - accuracy: 0.9010 - val_loss: 0.3286 - val_accuracy: 0.9195
# Epoch 10/100
# 49/49 [==============================] - 10s 204ms/step - loss: 0.3379 - accuracy: 0.9061 - val_loss: 0.3041 - val_accuracy: 0.9310
# Epoch 11/100
# 49/49 [==============================] - 10s 205ms/step - loss: 0.3101 - accuracy: 0.9195 - val_loss: 0.2880 - val_accuracy: 0.9425
# Epoch 12/100
# 49/49 [==============================] - 10s 202ms/step - loss: 0.2942 - accuracy: 0.9202 - val_loss: 0.2771 - val_accuracy: 0.9195
# Epoch 13/100
# 49/49 [==============================] - 10s 206ms/step - loss: 0.2765 - accuracy: 0.9234 - val_loss: 0.2564 - val_accuracy: 0.9310
# Epoch 14/100
# 49/49 [==============================] - 10s 209ms/step - loss: 0.2655 - accuracy: 0.9291 - val_loss: 0.2483 - val_accuracy: 0.9425
# Epoch 15/100
# 49/49 [==============================] - 10s 204ms/step - loss: 0.2486 - accuracy: 0.9330 - val_loss: 0.2338 - val_accuracy: 0.9310
# Epoch 16/100
# 49/49 [==============================] - 10s 203ms/step - loss: 0.2358 - accuracy: 0.9330 - val_loss: 0.2226 - val_accuracy: 0.9425
# Epoch 17/100
# 49/49 [==============================] - 10s 200ms/step - loss: 0.2280 - accuracy: 0.9355 - val_loss: 0.2106 - val_accuracy: 0.9425
# Epoch 18/100
# 49/49 [==============================] - 10s 208ms/step - loss: 0.2176 - accuracy: 0.9361 - val_loss: 0.2074 - val_accuracy: 0.9425
# Epoch 19/100
# 49/49 [==============================] - 10s 207ms/step - loss: 0.2099 - accuracy: 0.9381 - val_loss: 0.1982 - val_accuracy: 0.9425
# Epoch 20/100
# 49/49 [==============================] - 10s 202ms/step - loss: 0.2029 - accuracy: 0.9374 - val_loss: 0.1925 - val_accuracy: 0.9425
# Epoch 21/100
# 49/49 [==============================] - 10s 203ms/step - loss: 0.1962 - accuracy: 0.9419 - val_loss: 0.1854 - val_accuracy: 0.9425
# Epoch 22/100
# 49/49 [==============================] - 10s 200ms/step - loss: 0.1891 - accuracy: 0.9406 - val_loss: 0.1776 - val_accuracy: 0.9425
# Epoch 23/100
# 49/49 [==============================] - 10s 199ms/step - loss: 0.1838 - accuracy: 0.9413 - val_loss: 0.1745 - val_accuracy: 0.9540
# Epoch 24/100
# 49/49 [==============================] - 10s 205ms/step - loss: 0.1786 - accuracy: 0.9438 - val_loss: 0.1687 - val_accuracy: 0.9540
# Epoch 25/100
# 49/49 [==============================] - 10s 202ms/step - loss: 0.1712 - accuracy: 0.9457 - val_loss: 0.1642 - val_accuracy: 0.9540
# Epoch 26/100
# 49/49 [==============================] - 10s 204ms/step - loss: 0.1661 - accuracy: 0.9483 - val_loss: 0.1603 - val_accuracy: 0.9540
# Epoch 27/100
# 49/49 [==============================] - 10s 204ms/step - loss: 0.1619 - accuracy: 0.9502 - val_loss: 0.1542 - val_accuracy: 0.9655
# Epoch 28/100
# 49/49 [==============================] - 10s 210ms/step - loss: 0.1576 - accuracy: 0.9515 - val_loss: 0.1534 - val_accuracy: 0.9540
# Epoch 29/100
# 49/49 [==============================] - 10s 202ms/step - loss: 0.1534 - accuracy: 0.9540 - val_loss: 0.1477 - val_accuracy: 0.9655
# Epoch 30/100
# 49/49 [==============================] - 10s 201ms/step - loss: 0.1507 - accuracy: 0.9553 - val_loss: 0.1456 - val_accuracy: 0.9655
# Epoch 31/100
# 49/49 [==============================] - 10s 203ms/step - loss: 0.1451 - accuracy: 0.9559 - val_loss: 0.1431 - val_accuracy: 0.9655
# Epoch 32/100
# 49/49 [==============================] - 10s 210ms/step - loss: 0.1424 - accuracy: 0.9598 - val_loss: 0.1389 - val_accuracy: 0.9655
# Epoch 33/100
# 49/49 [==============================] - 10s 202ms/step - loss: 0.1401 - accuracy: 0.9591 - val_loss: 0.1372 - val_accuracy: 0.9655
# Epoch 34/100
# 49/49 [==============================] - 10s 200ms/step - loss: 0.1374 - accuracy: 0.9585 - val_loss: 0.1361 - val_accuracy: 0.9540
# Epoch 35/100
# 49/49 [==============================] - 10s 202ms/step - loss: 0.1328 - accuracy: 0.9591 - val_loss: 0.1317 - val_accuracy: 0.9655
# Epoch 36/100
# 49/49 [==============================] - 10s 204ms/step - loss: 0.1303 - accuracy: 0.9630 - val_loss: 0.1270 - val_accuracy: 0.9655
# Epoch 37/100
# 49/49 [==============================] - 10s 204ms/step - loss: 0.1258 - accuracy: 0.9649 - val_loss: 0.1275 - val_accuracy: 0.9655
# Epoch 38/100
# 49/49 [==============================] - 10s 200ms/step - loss: 0.1246 - accuracy: 0.9636 - val_loss: 0.1233 - val_accuracy: 0.9655
# Epoch 39/100
# 49/49 [==============================] - 10s 202ms/step - loss: 0.1218 - accuracy: 0.9655 - val_loss: 0.1226 - val_accuracy: 0.9655
# Epoch 40/100
# 49/49 [==============================] - 10s 206ms/step - loss: 0.1206 - accuracy: 0.9649 - val_loss: 0.1187 - val_accuracy: 0.9655
# Epoch 41/100
# 49/49 [==============================] - 10s 203ms/step - loss: 0.1197 - accuracy: 0.9642 - val_loss: 0.1181 - val_accuracy: 0.9655
# Epoch 42/100
# 49/49 [==============================] - 12s 246ms/step - loss: 0.1162 - accuracy: 0.9668 - val_loss: 0.1136 - val_accuracy: 0.9655
# Epoch 43/100
# 49/49 [==============================] - 11s 227ms/step - loss: 0.1123 - accuracy: 0.9681 - val_loss: 0.1146 - val_accuracy: 0.9655
# Epoch 44/100
# 49/49 [==============================] - 11s 228ms/step - loss: 0.1101 - accuracy: 0.9700 - val_loss: 0.1098 - val_accuracy: 0.9655
# Epoch 45/100
# 49/49 [==============================] - 11s 228ms/step - loss: 0.1098 - accuracy: 0.9681 - val_loss: 0.1085 - val_accuracy: 0.9655
# Epoch 46/100
# 49/49 [==============================] - 11s 218ms/step - loss: 0.1070 - accuracy: 0.9687 - val_loss: 0.1046 - val_accuracy: 0.9655
# Epoch 47/100
# 49/49 [==============================] - 11s 215ms/step - loss: 0.1030 - accuracy: 0.9719 - val_loss: 0.1064 - val_accuracy: 0.9655
# Epoch 48/100
# 49/49 [==============================] - 11s 220ms/step - loss: 0.1022 - accuracy: 0.9719 - val_loss: 0.1068 - val_accuracy: 0.9655
# Epoch 49/100
# 49/49 [==============================] - 12s 235ms/step - loss: 0.1003 - accuracy: 0.9719 - val_loss: 0.1002 - val_accuracy: 0.9655
# Epoch 50/100
# 49/49 [==============================] - 13s 258ms/step - loss: 0.1007 - accuracy: 0.9725 - val_loss: 0.1010 - val_accuracy: 0.9655
# Epoch 51/100
# 49/49 [==============================] - 11s 227ms/step - loss: 0.0983 - accuracy: 0.9745 - val_loss: 0.0972 - val_accuracy: 0.9655
# Epoch 52/100
# 49/49 [==============================] - 12s 237ms/step - loss: 0.0944 - accuracy: 0.9745 - val_loss: 0.0968 - val_accuracy: 0.9655
# Epoch 53/100
# 49/49 [==============================] - 11s 231ms/step - loss: 0.0933 - accuracy: 0.9745 - val_loss: 0.0967 - val_accuracy: 0.9655
# Epoch 54/100
# 49/49 [==============================] - 12s 235ms/step - loss: 0.0936 - accuracy: 0.9732 - val_loss: 0.0956 - val_accuracy: 0.9655
# Epoch 55/100
# 49/49 [==============================] - 12s 236ms/step - loss: 0.0913 - accuracy: 0.9764 - val_loss: 0.0952 - val_accuracy: 0.9655
# Epoch 56/100
# 49/49 [==============================] - 11s 223ms/step - loss: 0.0890 - accuracy: 0.9757 - val_loss: 0.0925 - val_accuracy: 0.9655
# Epoch 57/100
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0866 - accuracy: 0.9783 - val_loss: 0.0922 - val_accuracy: 0.9655
# Epoch 58/100
# 49/49 [==============================] - 11s 215ms/step - loss: 0.0850 - accuracy: 0.9789 - val_loss: 0.0907 - val_accuracy: 0.9655
# Epoch 59/100
# 49/49 [==============================] - 11s 214ms/step - loss: 0.0843 - accuracy: 0.9783 - val_loss: 0.0885 - val_accuracy: 0.9655
# Epoch 60/100
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0832 - accuracy: 0.9789 - val_loss: 0.0846 - val_accuracy: 0.9655
# Epoch 61/100
# 49/49 [==============================] - 11s 215ms/step - loss: 0.0818 - accuracy: 0.9777 - val_loss: 0.0881 - val_accuracy: 0.9655
# Epoch 62/100
# 49/49 [==============================] - 11s 233ms/step - loss: 0.0806 - accuracy: 0.9802 - val_loss: 0.0851 - val_accuracy: 0.9655
# Epoch 63/100
# 49/49 [==============================] - 12s 237ms/step - loss: 0.0794 - accuracy: 0.9796 - val_loss: 0.0837 - val_accuracy: 0.9655
# Epoch 64/100
# 49/49 [==============================] - 12s 240ms/step - loss: 0.0774 - accuracy: 0.9789 - val_loss: 0.0841 - val_accuracy: 0.9655
# Epoch 65/100
# 49/49 [==============================] - 12s 237ms/step - loss: 0.0767 - accuracy: 0.9796 - val_loss: 0.0819 - val_accuracy: 0.9655
# Epoch 66/100
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0758 - accuracy: 0.9783 - val_loss: 0.0821 - val_accuracy: 0.9655
# Epoch 67/100
# 49/49 [==============================] - 11s 229ms/step - loss: 0.0739 - accuracy: 0.9789 - val_loss: 0.0779 - val_accuracy: 0.9655
# Epoch 68/100
# 49/49 [==============================] - 11s 228ms/step - loss: 0.0730 - accuracy: 0.9802 - val_loss: 0.0809 - val_accuracy: 0.9655
# Epoch 69/100
# 49/49 [==============================] - 12s 241ms/step - loss: 0.0714 - accuracy: 0.9808 - val_loss: 0.0762 - val_accuracy: 0.9655
# Epoch 70/100
# 49/49 [==============================] - 13s 259ms/step - loss: 0.0706 - accuracy: 0.9815 - val_loss: 0.0763 - val_accuracy: 0.9655
# Epoch 71/100
# 49/49 [==============================] - 13s 267ms/step - loss: 0.0700 - accuracy: 0.9808 - val_loss: 0.0761 - val_accuracy: 0.9655
# Epoch 72/100
# 49/49 [==============================] - 13s 273ms/step - loss: 0.0687 - accuracy: 0.9802 - val_loss: 0.0756 - val_accuracy: 0.9655
# Epoch 73/100
# 49/49 [==============================] - 12s 238ms/step - loss: 0.0678 - accuracy: 0.9802 - val_loss: 0.0735 - val_accuracy: 0.9655
# Epoch 74/100
# 49/49 [==============================] - 11s 228ms/step - loss: 0.0660 - accuracy: 0.9808 - val_loss: 0.0716 - val_accuracy: 0.9655
# Epoch 75/100
# 49/49 [==============================] - 12s 235ms/step - loss: 0.0668 - accuracy: 0.9821 - val_loss: 0.0704 - val_accuracy: 0.9655
# Epoch 76/100
# 49/49 [==============================] - 12s 244ms/step - loss: 0.0647 - accuracy: 0.9808 - val_loss: 0.0732 - val_accuracy: 0.9655
# Epoch 77/100
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0638 - accuracy: 0.9828 - val_loss: 0.0729 - val_accuracy: 0.9655
# Epoch 78/100
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0625 - accuracy: 0.9828 - val_loss: 0.0693 - val_accuracy: 0.9655
# Epoch 79/100
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0623 - accuracy: 0.9828 - val_loss: 0.0681 - val_accuracy: 0.9655
# Epoch 80/100
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0614 - accuracy: 0.9821 - val_loss: 0.0665 - val_accuracy: 0.9655
# Epoch 81/100
# 49/49 [==============================] - 12s 251ms/step - loss: 0.0598 - accuracy: 0.9840 - val_loss: 0.0668 - val_accuracy: 0.9655
# Epoch 82/100
# 49/49 [==============================] - 11s 231ms/step - loss: 0.0594 - accuracy: 0.9834 - val_loss: 0.0643 - val_accuracy: 0.9770
# Epoch 83/100
# 49/49 [==============================] - 11s 225ms/step - loss: 0.0573 - accuracy: 0.9847 - val_loss: 0.0677 - val_accuracy: 0.9655
# Epoch 84/100
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0567 - accuracy: 0.9847 - val_loss: 0.0656 - val_accuracy: 0.9655
# Epoch 85/100
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0557 - accuracy: 0.9847 - val_loss: 0.0637 - val_accuracy: 0.9770
# Epoch 86/100
# 49/49 [==============================] - 12s 247ms/step - loss: 0.0556 - accuracy: 0.9840 - val_loss: 0.0625 - val_accuracy: 0.9770
# Epoch 87/100
# 49/49 [==============================] - 10s 194ms/step - loss: 0.0544 - accuracy: 0.9834 - val_loss: 0.0644 - val_accuracy: 0.9655
# Epoch 88/100
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0544 - accuracy: 0.9834 - val_loss: 0.0611 - val_accuracy: 0.9770
# Epoch 89/100
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0535 - accuracy: 0.9847 - val_loss: 0.0603 - val_accuracy: 0.9770
# Epoch 90/100
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0527 - accuracy: 0.9840 - val_loss: 0.0606 - val_accuracy: 0.9770
# Epoch 91/100
# 49/49 [==============================] - 9s 187ms/step - loss: 0.0520 - accuracy: 0.9847 - val_loss: 0.0616 - val_accuracy: 0.9655
# Epoch 92/100
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0506 - accuracy: 0.9860 - val_loss: 0.0579 - val_accuracy: 0.9770
# Epoch 93/100
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0512 - accuracy: 0.9866 - val_loss: 0.0565 - val_accuracy: 0.9770
# Epoch 94/100
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0501 - accuracy: 0.9853 - val_loss: 0.0565 - val_accuracy: 0.9770
# Epoch 95/100
# 49/49 [==============================] - 11s 215ms/step - loss: 0.0490 - accuracy: 0.9853 - val_loss: 0.0577 - val_accuracy: 0.9770
# Epoch 96/100
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0478 - accuracy: 0.9872 - val_loss: 0.0569 - val_accuracy: 0.9770
# Epoch 97/100
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0472 - accuracy: 0.9866 - val_loss: 0.0572 - val_accuracy: 0.9770
# Epoch 98/100
# 49/49 [==============================] - 10s 197ms/step - loss: 0.0474 - accuracy: 0.9866 - val_loss: 0.0563 - val_accuracy: 0.9770
# Epoch 99/100
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0460 - accuracy: 0.9872 - val_loss: 0.0555 - val_accuracy: 0.9770
# Epoch 100/100
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0452 - accuracy: 0.9885 - val_loss: 0.0553 - val_accuracy: 0.9770

# %% [markdown]
# # Training dan validation accurasi dan loss

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label = 'Training Accuracy')
plt.plot(epochs, val_acc, 'b', label = 'Validation Accuracy')
plt.title('Training and Validation accuracy')
plt.legend(loc = 'best')
plt.show()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Menampilkan precission, recall, dan f1-score

# %% [markdown]
# # VALIDATION

# %%
import numpy as np
from sklearn.metrics import classification_report

# Evaluasi model
y_true = valid_dataset.classes
Y_pred = modelku.predict(valid_dataset, verbose=1)
y_pred = np.argmax(Y_pred, axis=1)

# Tampilkan laporan klasifikasi
target_names = list(valid_dataset.class_indices.keys())
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 3/3 [==============================] - 2s 133ms/step
#               precision    recall  f1-score   support
#
#       GradeA       1.00      0.97      0.98        29
#       GradeB       0.94      1.00      0.97        29
#       GradeC       1.00      0.97      0.98        29
#
#     accuracy                           0.98        87
#    macro avg       0.98      0.98      0.98        87
# weighted avg       0.98      0.98      0.98        87

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

class_list = os.listdir(train_dir)

# membuat prediksi pada data validasi
y_pred = modelku.predict(valid_dataset)
y_pred = np.argmax(y_pred, axis=1)

# mengambil label yang sebenarnya
y_true = valid_dataset.classes

# membuat confusion matrix
cm = confusion_matrix(y_true, y_pred)

# menampilkan confusion matrix dengan heatmap
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', xticklabels=class_list, yticklabels=class_list)
plt.title('Confusion Matrix VALIDASI')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 3/3 [==============================] - 0s 136ms/step

# %% [markdown]
# # TESTING

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

class_list = os.listdir(train_dir)

# membuat prediksi pada data validasi
y_pred = modelku.predict(test_dataset)
y_pred = np.argmax(y_pred, axis=1)

# mengambil label yang sebenarnya
y_true = test_dataset.classes

# membuat confusion matrix
cm = confusion_matrix(y_true, y_pred)

# menampilkan confusion matrix dengan heatmap
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', xticklabels=class_list, yticklabels=class_list)
plt.title('Confusion Matrix TESTING')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 3/3 [==============================] - 1s 186ms/step

# %%
import numpy as np
from sklearn.metrics import classification_report

# Evaluasi model
y_true = test_dataset.classes
Y_pred = modelku.predict(test_dataset, verbose=1)
y_pred = np.argmax(Y_pred, axis=1)

# Tampilkan laporan klasifikasi
target_names = list(test_dataset.class_indices.keys())
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 3/3 [==============================] - 1s 197ms/step
#               precision    recall  f1-score   support
#
#       gradeA       0.97      1.00      0.98        29
#       gradeB       0.97      0.97      0.97        29
#       gradeC       1.00      0.97      0.98        29
#
#     accuracy                           0.98        87
#    macro avg       0.98      0.98      0.98        87
# weighted avg       0.98      0.98      0.98        87

# %% [markdown]
# # SAVE MODEL

# %%
modelku.save('model/RECT_coba2_BL00001_no-dropout_size96.h5')

# %% [markdown]
# # Export TFLITE

# %%
import tensorflow as tf

# Load the Keras model
model = tf.keras.models.load_model('model\RECT_coba2_BL00001_no-dropout_size96.h5')

# Convert the Keras model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TensorFlow Lite model
with open('tflite/RECT_coba2_BL00001_no-dropout_size96.tflite', 'wb') as f:
    f.write(tflite_model)

# # Convert the model
# converter = tf.lite.TFLiteConverter.from_saved_model("model\modelku-fit_data-baru_59.h5") # path to the SavedModel directory
# tflite_model = converter.convert()

# # Save the model.
# with open('export-3_blob-fit_no-dropout_59-quant.tflite', 'wb') as f:
#   f.write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\ronal\AppData\Local\Temp\tmppdwguqxq\assets
# INFO:tensorflow:Assets written to: C:\Users\ronal\AppData\Local\Temp\tmppdwguqxq\assets

# %% [markdown]
# # TES Klasifikasi

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

class_list = os.listdir(train_dir)

img_path = 'validasi\GradeB\imageB_432977.bmp'
img = image.load_img(img_path, target_size=(128, 128))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

preds = modelku.predict(x)
class_idx = np.argmax(preds[0])
class_label = class_list[class_idx]

imgplot = plt.imshow(img)
plt.title(f'Predicted Class: {class_label}')
plt.axis('off')
plt.show()
